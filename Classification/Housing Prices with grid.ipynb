# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import LinearRegression, RidgeCV, SGDClassifier
from sklearn import datasets

# %%
x,y = datasets.load_digits(return_X_y=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-b14f0afcacfc> in <module>()
# ----> 1 x,y = datasets.load_housing(return_X_y=True)
#
# AttributeError: module 'sklearn.datasets' has no attribute 'load_housing'

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
params = [{'n_jobs' : [i for i in range(10,3000,100)]}]

# %%
model = LinearRegression()

# %%
grid = GridSearchCV(model,params)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LinearRegression(copy_X=True, fit_intercept=True,
#                                         n_jobs=None, normalize=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'n_jobs': [10, 110, 210, 310, 410, 510, 610, 710, 810,
#                                      910, 1010, 1110, 1210, 1310, 1410, 1510,
#                                      1610, 1710, 1810, 1910, 2010, 2110, 2210,
#                                      2310, 2410, 2510, 2610, 2710, 2810,
#                                      2910]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
grid.best_score_
# Out:
# 0.5420737720269703

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(x_test,y_test)
# Out:
# 0.6015661158822607
